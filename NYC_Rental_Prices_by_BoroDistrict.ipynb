# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
#import numpy as np
#import dateutil

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
nyc_rental_load = "\\Users\\Paul-DS\\Downloads\\Neighborhood_Zri_AllHomesPlusMultifamily.csv"
nyc_rental_data=pd.read_csv(nyc_rental_load)
#nyc_mean_price_sales = "Resources/nyc_mean_price_per_sqft.csv"
#nyc_price_per_sqft = pd.read_csv(nyc_mean_price_sales)

# %%
manhattan_rent = nyc_rental_data[nyc_rental_data["CountyName"]=="New York"]

# %%
manhattan_rent_mean = manhattan_rent.drop(columns=["RegionID","City","State","Metro","SizeRank","CountyName"])

# %%
manhattan_region=[]
manhattan_region = manhattan_rent_mean['RegionName'].unique()

# %%
manhattan_region
# Out:
# array(['Upper West Side', 'Upper East Side', 'Washington Heights',
#        'Harlem', 'East Harlem', 'Lower East Side', 'East Village',
#        'Gramercy', 'Hamilton Heights', 'Chelsea', 'Greenwich Village',
#        'Morningside Heights', 'Financial District', 'Flatiron District',
#        'West Village', 'Brooklyn Heights', 'Sutton Place', 'Turtle Bay',
#        'Midtown', 'Tudor City', 'Battery Park', 'Roosevelt Island',
#        'Murray Hill', 'Little Italy', 'NoHo', 'Garment District'],
#       dtype=object)

# %%
nyc_region_rent={}
for region in manhattan_region:
    nyc_region_rent[region] = nyc_rental_data[nyc_rental_data["RegionName"]==region]
    nyc_region_rent[region] = nyc_region_rent[region].drop(columns=["RegionID","RegionName","City","State","Metro","SizeRank","CountyName"]).mean()
    nyc_region_rent[region] = pd.DataFrame(nyc_region_rent[region],columns=[region+' rental price'])

# %%
nyc_region_rent[region].index.rename('Date')
# Out:
# Index(['2010-11', '2010-12', '2011-01', '2011-02', '2011-03', '2011-04',
#        '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10',
#        '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04',
#        '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10',
#        '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04',
#        '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10',
#        '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04',
#        '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10',
#        '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04',
#        '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10',
#        '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04',
#        '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10',
#        '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04',
# ...

# %%
#nyc_region_rent
for region in manhattan_region:
    nyc_region_rent[region].index.rename('Date',inplace=True)
    #manhattan_region_df = manhattan_region_df.concat(nyc_region_rent[region])
    #manhattan_region_df = manhattan_region_df.join(nyc_region_rent[region])
#nyc_region_rent

# %%
first=0
for region in manhattan_region:
    if first==0:
        df = pd.DataFrame(nyc_region_rent[region])
    else:
        df = df.join(pd.DataFrame(nyc_region_rent[region]))
    first=1

# %%
df
# Out:
#          Upper West Side rental price  Upper East Side rental price  \
# Date
# 2010-11                           NaN                   5971.000000
# 2010-12                           NaN                   6009.000000
# 2011-01                           NaN                   6041.000000
# 2011-02                           NaN                   6066.000000
# 2011-03                           NaN                   6084.000000
# 2011-04                           NaN                   6110.000000
# 2011-05                           NaN                   6144.000000
# 2011-06                           NaN                   6180.000000
# 2011-07                           NaN                   6205.000000
# 2011-08                           NaN                   6212.000000
# 2011-09                           NaN                   6224.000000
# 2011-10                           NaN                   6232.000000
# 2011-11                           NaN                   6240.000000
# ...

# %%
#df = df.dropna(axis=0)

# %%
df.index
# Out:
# Index(['2010-11', '2010-12', '2011-01', '2011-02', '2011-03', '2011-04',
#        '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10',
#        '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04',
#        '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10',
#        '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04',
#        '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10',
#        '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04',
#        '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10',
#        '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04',
#        '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10',
#        '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04',
#        '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10',
#        '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04',
# ...

# %%
df.to_csv("\\Users\\Paul-DS\\Downloads\\NYC_Rental_Prices_by_BoroDistrict.csv")
