# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
#import numpy as np
#import dateutil
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')


# this code written by Paul AG

manhattan_crime_precinct=pd.read_csv("manhattan_precinct_Crime_Cnt.csv")

boro=['Manhattan', 'Bronx', 'Brooklyn', 'Queens', 'Staten Island']
# Kings is synomous with Brooklyn (same land mass)
county=['New York', 'Bronx', 'Kings', 'Queens', 'Richmond']

# %%
df=manhattan_crime_precinct['YR_M'].str.split('-',expand=True)

# %%
manhattan_crime_precinct=manhattan_crime_precinct.join(df)

# %%
manhattan_crime_precinct=manhattan_crime_precinct.rename(columns={0:'Date'})

# %%
manhattan_crime_precinct=manhattan_crime_precinct.drop(columns=[1])

# %%
manhattan_crime_precinct=manhattan_crime_precinct.drop(columns=['YR_M']).groupby(['Date','Manhattan Precinct']).sum()

# %%
manhattan_crime_precinct.sum()
# Out:
# MANHATTAN_precinct_Crime_Cnt    690946
# dtype: int64

# %%
manhattan_crime_precinct=manhattan_crime_precinct.reset_index()

# %%
manhattan_crime_precinct.set_index('Date')
# Out:
#       Manhattan Precinct  MANHATTAN_precinct_Crime_Cnt
# Date
# 2012                 1.0                          6324
# 2012                 5.0                          4696
# 2012                 6.0                          5547
# 2012                 7.0                          4171
# 2012                 9.0                          6316
# 2012                10.0                          4272
# 2012                13.0                          7168
# 2012                14.0                         11489
# 2012                17.0                          3259
# 2012                18.0                          7923
# 2012                19.0                          6425
# 2012                20.0                          4094
# 2012                22.0                           524
# 2012                23.0                          6269
# 2012                24.0                          4842
# 2012                25.0                          6916
# ...

# %%
manhattan_crime_precinct.plot.bar()

# %%
manhattan_crime_precinct_2017=manhattan_crime_precinct[manhattan_crime_precinct['Date']=='2017']

# %%
manhattan_crime_precinct_2017=manhattan_crime_precinct_2017.drop(columns=['Date'])

# %%
manhattan_crime_precinct_2017.head()
# Out:
#      Manhattan Precinct  MANHATTAN_precinct_Crime_Cnt
# 110                 1.0                          5933
# 111                 5.0                          4195
# 112                 6.0                          4942
# 113                 7.0                          4200
# 114                 9.0                          4991

# %%
manhattan_crime_precinct_2017=manhattan_crime_precinct_2017.set_index('Manhattan Precinct')

# %%
manhattan_crime_precinct_2017.to_csv("\\Users\\Paul-DS\\Downloads\\Manhattan_Crime_by_Precinct_YR2017.csv")

# %%
manhattan_crime_precinct_2017.plot.bar()
